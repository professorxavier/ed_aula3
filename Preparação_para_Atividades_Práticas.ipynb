# %% [markdown]
# <a href="https://colab.research.google.com/github/professorxavier/ed_aula3/blob/exemplo/Prepara%C3%A7%C3%A3o_para_Atividades_Pr%C3%A1ticas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exemplos

# %%
nome = input("Qual é o seu nome?")
print("Olá,",  nome)
# Out:
# Qual é o seu nome?Fernando
# Olá, Fernando
